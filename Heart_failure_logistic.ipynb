# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv(r"C:\Users\YASHAS\OneDrive\Desktop\SEM 5 3rd year\ANN CASE STUDY\heart_failure_clinical_records_dataset.csv")
#df.head()
df.sample(5)
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 18   70.0        1                       125         0                 25
# 180  40.0        0                       478         1                 30
# 106  55.0        0                       748         0                 45
# 31   85.0        0                        23         0                 45
# 114  60.0        1                       754         1                 40
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 18                     1   237000.0               1.0           140    0
# 180                    0   303000.0               0.9           136    1
# 106                    0   263000.0               1.3           137    1
# 31                     0   360000.0               3.0           132    1
# 114                    1   328000.0               1.2           126    1
#
#      smoking  time  DEATH_EVENT
# 18         0    15            1
# ...

# %%
#using seaborn to create stat graph
import seaborn as sns
sns.set(style='whitegrid' , context='notebook')
cols = ['age','anaemia','creatinine_phosphokinase','ejection_fraction','high_blood_pressure','platelets','serum_creatinine','serum_sodium','sex','smoking','time','DEATH_EVENT']

# %%
#finding the correlation coefficant 
import numpy as np
cm = np.corrcoef(df[cols].values.T)
cm
# Out:
# array([[ 1.        ,  0.08800644, -0.0815839 ,  0.06009836,  0.09328868,
#         -0.05235437,  0.15918713, -0.04596584,  0.06542952,  0.01866787,
#         -0.22406842,  0.25372854],
#        [ 0.08800644,  1.        , -0.19074103,  0.03155697,  0.038182  ,
#         -0.04378555,  0.0521736 ,  0.04188161, -0.09476896, -0.10728984,
#         -0.14141398,  0.0662701 ],
#        [-0.0815839 , -0.19074103,  1.        , -0.04407955, -0.07058998,
#          0.02446339, -0.01640848,  0.05955016,  0.07979063,  0.00242124,
#         -0.00934565,  0.06272816],
#        [ 0.06009836,  0.03155697, -0.04407955,  1.        ,  0.02444473,
#          0.07217747, -0.01130247,  0.17590228, -0.14838597, -0.06731457,
#          0.04172924, -0.26860331],
#        [ 0.09328868,  0.038182  , -0.07058998,  0.02444473,  1.        ,
#          0.04996348, -0.00493453,  0.03710947, -0.10461463, -0.05571137,
#         -0.19643948,  0.07935106],
# ...

# %%
#plot rectangular data as a colour-encoded matrix
f, ax = plt.subplots(figsize=(15,10))
sns.set(font_scale=1.5)
hm = sns.heatmap(cm,
                cbar=True,
                annot=True,
                square=True,
                fmt='.2f' ,
                annot_kws={'size': 15},
                yticklabels=cols,
                xticklabels=cols)

# %%
#creating input dataframes
x=df[['age','anaemia','creatinine_phosphokinase','ejection_fraction','high_blood_pressure','platelets','serum_creatinine','serum_sodium','sex','smoking','time']].values
y=df[['DEATH_EVENT']].values

# %%
# Preparing Training and Testing datasets

# %%
#Splitting the dataset for training and testing

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=0)

# %%
#Applying LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression( C=0.1, penalty= 'l1',solver='liblinear')
model.fit(x_train,y_train)
# Out:
# C:\Users\YASHAS\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(C=0.1, penalty='l1', solver='liblinear')

# %%
model.score(x_train, y_train)
# Out:
# 0.8516746411483254

# %%
#reporting accuracy

# %%
print('Training accuracy: %.2f' % model.score(x_train,y_train))
# Out:
# Training accuracy: 0.85

# %%
print('Testing accuracy: %.2f' % model.score(x_test,y_test))
# Out:
# Testing accuracy: 0.79
